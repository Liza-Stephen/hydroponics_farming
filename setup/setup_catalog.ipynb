# %%
# %sql

CREATE CATALOG IF NOT EXISTS hydroponics;

# %%
# %sql

USE CATALOG hydroponics;

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS hydroponics.bronze;
CREATE SCHEMA IF NOT EXISTS hydroponics.silver;
CREATE SCHEMA IF NOT EXISTS hydroponics.gold;

# %%
# %sql

SHOW DATABASES FROM hydroponics;

# %%
# %sql

# DROP CATALOG IF EXISTS hydroponics CASCADE;
